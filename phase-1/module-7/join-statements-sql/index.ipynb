# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of `JOIN` statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# * Write SQL queries that make use of various types of joins
# * Compare and contrast the various types of joins
# * Discuss how primary and foreign keys are used in SQL
# * Decide and perform whichever type of join is best for retrieving desired data

# %% [markdown]
# ## CRM ERD
#
# In this lab, you'll use the same customer relationship management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database `'data.sqlite'`.

# %%
# Your code here
import pandas as pd
import sqlite3

conn = sqlite3.connect('data.sqlite')
cur = conn.cursor()

# %% [markdown]
# ## Select the names of all employees in Boston
#
# Hint: join the employees and offices tables. Select the first and last name.

# %%
offices = """
SELECT * 
FROM offices
"""
pd.read_sql(boston_offices,conn)
# Out:
#    officeCode           city             phone              addressLine1  \
# 0           1  San Francisco   +1 650 219 4782         100 Market Street
# 1           2         Boston   +1 215 837 0825          1550 Court Place
# 2           3            NYC   +1 212 555 3000      523 East 53rd Street
# 3           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 4           5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 5           6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 6           7         London  +44 20 7877 2041       25 Old Broad Street
# 7          27         Boston   +1 977 299 8345      105 Cambridge Street
#
#   addressLine2       state    country postalCode territory
# 0    Suite 300          CA        USA      94080        NA
# 1    Suite 102          MA        USA      02107        NA
# 2      apt. 5A          NY        USA      10022        NA
# 3                              France      75017      EMEA
# ...

# %%
emps = """
SELECT *
FROM employees
;
"""
pd.read_sql(emps, conn)
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %%
# Your code here
qry_bos_emps = """
SELECT lastname, firstname, employees.officecode
FROM employees
JOIN offices
    ON employees.officeCode = offices.officeCode
WHERE (employees.officeCode = 2) OR (employees.officeCode = 27)
;
"""

pd.read_sql(qry_bos_emps,conn)
# Out:
#     lastName firstName  officeCode
# 0   Firrelli     Julie           2
# 1  Patterson     Steve           2

# %% [markdown]
# ## Are there any offices that have zero employees?
# Hint: Combine the employees and offices tables and use a group by. Select the office code, city, and number of employees.

# %%
# Your code here
qry_empty_office = """
SELECT 
    offs.officeCode,
    offs.city,
    COUNT(emps.employeeNumber) as num_of_emps
FROM offices AS offs
LEFT JOIN employees AS emps
    USING (officeCode)
GROUP BY officeCode
HAVING num_of_emps = 0
;
"""
pd.read_sql(qry_empty_office,conn)
# Out:
#    officeCode    city  num_of_emps
# 0          27  Boston            0

# %%
qry = """
SELECT *
FROM customers
;
"""
pd.read_sql(qry,conn)
# Out:
#      customerNumber                    customerName contactLastName  \
# 0               103               Atelier graphique         Schmitt
# 1               112              Signal Gift Stores            King
# 2               114      Australian Collectors, Co.        Ferguson
# 3               119               La Rochelle Gifts         Labrune
# 4               121              Baane Mini Imports      Bergulfsen
# ..              ...                             ...             ...
# 117             486    Motor Mint Distributors Inc.         Salazar
# 118             487        Signal Collectibles Ltd.          Taylor
# 119             489  Double Decker Gift Stores, Ltd           Smith
# 120             495            Diecast Collectables          Franco
# 121             496               Kelly's Gift Shop         Snowden
#
#     contactFirstName           phone                  addressLine1  \
# 0            Carine       40.32.2555                54, rue Royale
# ...

# %% [markdown]
# ## Write 3 questions of your own and answer them

# %%
# Answers will vary

# Example question: 
"""
How many customers are there per office?
"""
# qry_custms_per_office = """
# SELECT 
#     offs.officeCode,
#     offs.city,
#     COUNT(custms.customerNumber) as num_of_custms
# FROM offices AS offs
# LEFT JOIN customers AS custms 
#     USING (postalCode)
# GROUP BY postalCode
# """
# pd.read_sql(qry_custms_per_office,conn)
# Out:
# '\nHow many customers are there per office?\n'

# %%
"""
How many employees are there per office? 
"""
qry_emps_per_office = """
SELECT 
    offs.officeCode,
    offs.city,
    COUNT(emps.employeeNumber) as num_of_emps
FROM offices AS offs
LEFT JOIN employees AS emps
    USING (officeCode)
GROUP BY officeCode
HAVING num_of_emps > 0
"""
pd.read_sql(qry_emps_per_office,conn)
# Out:
#    officeCode           city  num_of_emps
# 0           1  San Francisco            6
# 1           2         Boston            2
# 2           3            NYC            2
# 3           4          Paris            5
# 4           5          Tokyo            2
# 5           6         Sydney            4
# 6           7         London            2

# %%
"""
How many customers are there per employee?
"""

# Your code here
custms_per_emp = """
SELECT 
    emps.employeeNumber,
    emps.lastName,
    emps.firstName,
    COUNT(custms.customerNumber) AS num_of_custms
FROM employees AS emps
LEFT JOIN customers AS custms
    ON emps.employeeNumber = custms.salesRepEmployeeNumber
GROUP BY employeeNumber
;
"""
customers_per_employee_df = pd.read_sql(custms_per_emp,conn)
customers_per_employee_df
# Out:
#     employeeNumber   lastName firstName  num_of_custms
# 0             1002     Murphy     Diane              0
# 1             1056  Patterson      Mary              0
# 2             1076   Firrelli      Jeff              0
# 3             1088  Patterson   William              0
# 4             1102     Bondur    Gerard              0
# 5             1143        Bow   Anthony              0
# 6             1165   Jennings    Leslie              6
# 7             1166   Thompson    Leslie              6
# 8             1188   Firrelli     Julie              6
# 9             1216  Patterson     Steve              6
# 10            1286      Tseng  Foon Yue              7
# 11            1323     Vanauf    George              8
# 12            1337     Bondur      Loui              6
# 13            1370  Hernandez    Gerard              7
# 14            1401   Castillo    Pamela             10
# 15            1501       Bott     Larry              8
# ...

# %%
"""
How many employees have zero customers
"""

# Your code here
zero_sum = 0
for item in customers_per_employee_df['num_of_custms']:
    if item == 0 :
        zero_sum += 1
print(f'There are {zero_sum} employees who have no active customers')
    
# pd.read_sql(qry_unproductive,conn)
# Out:
# There are 8 employees who have no active customers

# %% [markdown]
# ## Level Up 1: Display the names of every individual product that each employee has sold
#
# Hint: You will need to use multiple `JOIN` clauses to connect all the way from employee names to product names.

# %%
# Your code here
products_by_employee = """
SELECT firstName, lastName, productName
FROM employees AS emps
JOIN customers AS cstms
    ON emps.employeeNumber = cstms.salesRepEmployeeNumber
JOIN orders
    USING(customerNumber)
JOIN orderdetails
    USING(orderNumber)
JOIN products
    USING(productCode)
;
"""
df = pd.read_sql(products_by_employee, conn)
df
# Out:
#      firstName  lastName                                  productName
# 0       Leslie  Jennings                               1958 Setra Bus
# 1       Leslie  Jennings                       1940 Ford Pickup Truck
# 2       Leslie  Jennings                      1939 Cadillac Limousine
# 3       Leslie  Jennings  1996 Peterbilt 379 Stake Bed with Outrigger
# 4       Leslie  Jennings                            1968 Ford Mustang
# ...        ...       ...                                          ...
# 2991    Martin    Gerard                  1954 Greyhound Scenicruiser
# 2992    Martin    Gerard       1950's Chicago Surface Lines Streetcar
# 2993    Martin    Gerard             Diamond T620 Semi-Skirted Tanker
# 2994    Martin    Gerard                           1911 Ford Town Car
# 2995    Martin    Gerard             1936 Mercedes Benz 500k Roadster
#
# [2996 rows x 3 columns]

# %% [markdown]
# ## Level Up 2: Display the number of products each employee has sold
#
# Alphabetize the results by employee last name.
#
# Hint: Use the `quantityOrdered` column from `orderDetails`. Also, think about how to group the data when some employees might have the same first or last name.

# %%
# Your code here
num_prod_by_emp = """
SELECT firstName, lastName, SUM(quantityOrdered) as total_products_sold
FROM employees AS e
JOIN customers AS c
    ON e.employeeNumber = c.salesRepEmployeeNumber
JOIN orders
    USING(customerNumber)
JOIN orderdetails
    USING(orderNumber)
GROUP BY firstName, lastName
ORDER BY lastName
;
"""
pd.read_sql(num_prod_by_emp, conn)
# Out:
#    firstName   lastName  total_products_sold
# 0       Loui     Bondur                 6186
# 1      Larry       Bott                 8205
# 2     Pamela   Castillo                 9290
# 3      Julie   Firrelli                 4227
# 4       Andy     Fixter                 6246
# 5     Martin     Gerard                 4180
# 6     Gerard  Hernandez                14231
# 7     Leslie   Jennings                11854
# 8      Barry      Jones                 7486
# 9      Peter      Marsh                 6632
# 10      Mami      Nishi                 4923
# 11     Steve  Patterson                 5561
# 12    Leslie   Thompson                 4056
# 13  Foon Yue      Tseng                 5016
# 14    George     Vanauf                 7423

# %% [markdown]
# ## Level Up 3: Display the names employees who have sold more than 200 different products
#
# Hint: this is different from the previous question because the quantity sold doesn't matter, only the number of different products

# %%
# Your code here
q = """
SELECT firstName, lastName, COUNT(productCode) as different_products_sold
FROM employees AS e
JOIN customers AS c
    ON e.employeeNumber = c.salesRepEmployeeNumber
JOIN orders
    USING(customerNumber)
JOIN orderdetails
    USING(orderNumber)
GROUP BY firstName, lastName
HAVING different_products_sold > 200
ORDER BY lastName
;
"""
pd.read_sql(q, conn)
# Out:
#   firstName   lastName  different_products_sold
# 0     Larry       Bott                      236
# 1    Pamela   Castillo                      272
# 2    Gerard  Hernandez                      396
# 3    Leslie   Jennings                      331
# 4     Barry      Jones                      220
# 5    George     Vanauf                      211

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You practiced using join statements and leveraged your foreign keys knowledge!
